# %% [markdown]
# # COVID-19 Interactive Analysis Dashboard

# %% [markdown]
# ## What is COVID-19?
#
# > Coronaviruses are a large family of viruses that may cause respiratory illnesses in humans ranging from common colds to more severe conditions such as Severe Acute Respiratory Syndrome (SARS) and Middle Eastern Respiratory Syndrome (MERS).1
# 'Novel coronavirus' is a new, previously unidentified strain of coronavirus. The novel coronavirus involved in the current outbreak has been named SARS-CoV-2 by the World Health Organization (WHO). 3The disease it causes has been named “coronavirus disease 2019” (or “COVID-19”).`
#
# ![Coronavirus particle Image](https://www.apta.com/wp-content/uploads/home-banner-1.jpg)

# %%
# importing libraries

from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
from IPython.core.display import display, HTML

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import folium
import plotly.graph_objects as go
import plotly.offline as pyo
import seaborn as sns
import ipywidgets as widgets



from matplotlib import style
style.use('ggplot')
# %matplotlib inline
import cufflinks as cf
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot
plt.rcParams['figure.figsize'] = 25, 12

pyo.init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# loading data right from the source:
death_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv')
confirmed_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
recovered_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv')
country_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/web-data/data/cases_country.csv')
df=pd.read_csv(r'https://raw.githubusercontent.com/rahulagarwal01/Covid_19_Datasets/master/Covid%20cases%20in%20India.csv')

# %%
# confirmed_df.head()

# %%
# recovered_df.head()

# %%
# death_df.head()

# %%
# country_df.head()

# %%
# data cleaning

df.drop(['S. No.'],axis=1,inplace=True)
df['Total Cases']=df['Total Confirmed cases (Indian National)']+df['Total Confirmed cases ( Foreign National )']


# renaming the df column names to lowercase
country_df.columns = map(str.lower, country_df.columns)
confirmed_df.columns = map(str.lower, confirmed_df.columns)
death_df.columns = map(str.lower, death_df.columns)
recovered_df.columns = map(str.lower, recovered_df.columns)

# changing province/state to state and country/region to country
confirmed_df = confirmed_df.rename(columns={'province/state': 'state', 'country/region': 'country'})
recovered_df = confirmed_df.rename(columns={'province/state': 'state', 'country/region': 'country'})
death_df = death_df.rename(columns={'province/state': 'state', 'country/region': 'country'})
country_df = country_df.rename(columns={'country_region': 'country'})
# country_df.head()

# %% [markdown]
# # COVID-19 India Stats

# %%
# total number of confirmed, death and recovered cases
confirmed_total = int(country_df['confirmed'].sum())
deaths_total = int(country_df['deaths'].sum())
recovered_total = int(country_df['recovered'].sum())
active_total = int(country_df['active'].sum())

#For India
TOTAL_CASES_OVERALL=df['Total Cases'].sum()
df['Active Cases']=df['Total Cases']-df['Death']-df['Cured']
df.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_aaa62634_9e83_11ea_9480_e442a6e5747crow0_col1 {
#             background-color:  #fedccd;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow0_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow0_col3 {
#             background-color:  #fdd4c2;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow0_col4 {
#             background-color:  #fee5d9;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow0_col5 {
#             background-color:  #fedccd;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow0_col6 {
#             background-color:  #fedccd;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow1_col1 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow1_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow1_col3 {
#             background-color:  #fff0e8;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow1_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow1_col5 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow1_col6 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow2_col1 {
#             background-color:  #fc9474;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow2_col2 {
#             background-color:  #fee9df;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow2_col3 {
#             background-color:  #79040f;
#             color:  #f1f1f1;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow2_col4 {
#             background-color:  #fdd1be;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow2_col5 {
#             background-color:  #fc9474;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow2_col6 {
#             background-color:  #fcaf93;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow3_col1 {
#             background-color:  #fc8767;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow3_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow3_col3 {
#             background-color:  #fca98c;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow3_col4 {
#             background-color:  #fc8b6b;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow3_col5 {
#             background-color:  #fc8767;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow3_col6 {
#             background-color:  #fc8262;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow4_col1 {
#             background-color:  #ffeee7;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow4_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow4_col3 {
#             background-color:  #fdcebb;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow4_col4 {
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow4_col5 {
#             background-color:  #ffeee6;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow4_col6 {
#             background-color:  #fff1ea;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow5_col1 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow5_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow5_col3 {
#             background-color:  #fff2eb;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow5_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow5_col5 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow5_col6 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow6_col1 {
#             background-color:  #feeae0;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow6_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow6_col3 {
#             background-color:  #fdd2bf;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow6_col4 {
#             background-color:  #ffebe2;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow6_col5 {
#             background-color:  #feeae0;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow6_col6 {
#             background-color:  #ffece4;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow7_col1 {
#             background-color:  #feeae0;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow7_col2 {
#             background-color:  #fb694a;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow7_col3 {
#             background-color:  #fc8f6f;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow7_col4 {
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow7_col5 {
#             background-color:  #feeae0;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow7_col6 {
#             background-color:  #fff2eb;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow8_col1 {
#             background-color:  #fcb79c;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow8_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow8_col3 {
#             background-color:  #fcbea5;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow8_col4 {
#             background-color:  #fcad90;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow8_col5 {
#             background-color:  #fcb79c;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow8_col6 {
#             background-color:  #fcb69b;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow9_col1 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow9_col2 {
#             background-color:  #fdc6b0;
#             color:  #000000;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow9_col3 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow9_col4 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow9_col5 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_aaa62634_9e83_11ea_9480_e442a6e5747crow9_col6 {
#             background-color:  #67000d;
#             color:  #f1f1f1;

# %% [markdown]
# # COVID-19 Total Active Cases in India

# %%
Total_Active_Cases= df.groupby('Name of State / UT')['Active Cases'].sum().sort_values(ascending=False).to_frame()
Total_Active_Cases.style.background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
#     #T_24c3206e_9e81_11ea_a667_e442a6e5747crow0_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_24c3206e_9e81_11ea_a667_e442a6e5747crow1_col0 {
#             background-color:  #8abfdd;
#             color:  #000000;
#         }    #T_24c3206e_9e81_11ea_a667_e442a6e5747crow2_col0 {
#             background-color:  #afd1e7;
#             color:  #000000;
#         }    #T_24c3206e_9e81_11ea_a667_e442a6e5747crow3_col0 {
#             background-color:  #bad6eb;
#             color:  #000000;
#         }    #T_24c3206e_9e81_11ea_a667_e442a6e5747crow4_col0 {
#             background-color:  #c1d9ed;
#             color:  #000000;
#         }    #T_24c3206e_9e81_11ea_a667_e442a6e5747crow5_col0 {
#             background-color:  #c8dcf0;
#             color:  #000000;
#         }    #T_24c3206e_9e81_11ea_a667_e442a6e5747crow6_col0 {
#             background-color:  #d5e5f4;
#             color:  #000000;
#         }    #T_24c3206e_9e81_11ea_a667_e442a6e5747crow7_col0 {
#             background-color:  #dce9f6;
#             color:  #000000;
#         }    #T_24c3206e_9e81_11ea_a667_e442a6e5747crow8_col0 {
#             background-color:  #dce9f6;
#             color:  #000000;
#         }    #T_24c3206e_9e81_11ea_a667_e442a6e5747crow9_col0 {
#             background-color:  #e8f1fa;
#             color:  #000000;
#         }    #T_24c3206e_9e81_11ea_a667_e442a6e5747crow10_col0 {
#             background-color:  #eaf3fb;
#             color:  #000000;
#         }    #T_24c3206e_9e81_11ea_a667_e442a6e5747crow11_col0 {
#             background-color:  #edf4fc;
#             color:  #000000;
#         }    #T_24c3206e_9e81_11ea_a667_e442a6e5747crow12_col0 {
#             background-color:  #f0f6fd;
#             color:  #000000;
#         }    #T_24c3206e_9e81_11ea_a667_e442a6e5747crow13_col0 {
#             background-color:  #f2f8fd;
#             color:  #000000;
#         }    #T_24c3206e_9e81_11ea_a667_e442a6e5747crow14_col0 {
#             background-color:  #f3f8fe;
#             color:  #000000;
#         }    #T_24c3206e_9e81_11ea_a667_e442a6e5747crow15_col0 {
#             background-color:  #f3f8fe;
#             color:  #000000;
#         }    #T_24c3206e_9e81_11ea_a667_e442a6e5747crow16_col0 {
#             background-color:  #f5fafe;
#             color:  #000000;
#         }    #T_24c3206e_9e81_11ea_a667_e442a6e5747crow17_col0 {
#             background-color:  #f5fafe;
#             color:  #000000;
#         }    #T_24c3206e_9e81_11ea_a667_e442a6e5747crow18_col0 {
#             background-color:  #f6faff;
#             color:  #000000;
#         }    #T_24c3206e_9e81_11ea_a667_e442a6e5747crow19_col0 {
#             background-color:  #f6faff;
#             color:  #000000;
#         }    #T_24c3206e_9e81_11ea_a667_e442a6e5747crow20_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_24c3206e_9e81_11ea_a667_e442a6e5747crow21_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_24c3206e_9e81_11ea_a667_e442a6e5747crow22_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_24c3206e_9e81_11ea_a667_e442a6e5747crow23_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_24c3206e_9e81_11ea_a667_e442a6e5747crow24_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_24c3206e_9e81_11ea_a667_e442a6e5747crow25_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_24c3206e_9e81_11ea_a667_e442a6e5747crow26_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_24c3206e_9e81_11ea_a667_e442a6e5747crow27_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_24c3206e_9e81_11ea_a667_e442a6e5747crow28_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_24c3206e_9e81_11ea_a667_e442a6e5747crow29_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_24c3206e_9e81_11ea_a667_e442a6e5747crow30_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }</style><table id="T_24c3206e_9e81_11ea_a667_e442a6e5747c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Active Cases</th>    </tr>    <tr>        <th class="index_name level0" >Name of State / UT</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_24c3206e_9e81_11ea_a667_e442a6e5747clevel0_row0" class="row_heading level0 row0" >Maharashtra</th>
#                         <td id="T_24c3206e_9e81_11ea_a667_e442a6e5747crow0_col0" class="data row0 col0" >5307</td>
#             </tr>
#             <tr>
#                         <th id="T_24c3206e_9e81_11ea_a667_e442a6e5747clevel0_row1" class="row_heading level0 row1" >Gujarat</th>
#                         <td id="T_24c3206e_9e81_11ea_a667_e442a6e5747crow1_col0" class="data row1 col0" >2254</td>
#             </tr>
#             <tr>
#                         <th id="T_24c3206e_9e81_11ea_a667_e442a6e5747clevel0_row2" class="row_heading level0 row2" >Rajasthan</th>
#                         <td id="T_24c3206e_9e81_11ea_a667_e442a6e5747crow2_col0" class="data row2 col0" >1707</td>
#             </tr>
#             <tr>
#                         <th id="T_24c3206e_9e81_11ea_a667_e442a6e5747clevel0_row3" class="row_heading level0 row3" >Delhi</th>
#                         <td id="T_24c3206e_9e81_11ea_a667_e442a6e5747crow3_col0" class="data row3 col0" >1519</td>
#             </tr>
#             <tr>
#                         <th id="T_24c3206e_9e81_11ea_a667_e442a6e5747clevel0_row4" class="row_heading level0 row4" >Madhya Pradesh</th>
#                         <td id="T_24c3206e_9e81_11ea_a667_e442a6e5747crow4_col0" class="data row4 col0" >1413</td>
#             </tr>
#             <tr>
#                         <th id="T_24c3206e_9e81_11ea_a667_e442a6e5747clevel0_row5" class="row_heading level0 row5" >Uttar Pradesh</th>
#                         <td id="T_24c3206e_9e81_11ea_a667_e442a6e5747crow5_col0" class="data row5 col0" >1281</td>
#             </tr>
#             <tr>
#                         <th id="T_24c3206e_9e81_11ea_a667_e442a6e5747clevel0_row6" class="row_heading level0 row6" >Tamil Nadu</th>
#                         <td id="T_24c3206e_9e81_11ea_a667_e442a6e5747crow6_col0" class="data row6 col0" >911</td>
#             </tr>
#             <tr>
#                         <th id="T_24c3206e_9e81_11ea_a667_e442a6e5747clevel0_row7" class="row_heading level0 row7" >Telengana</th>
#                         <td id="T_24c3206e_9e81_11ea_a667_e442a6e5747crow7_col0" class="data row7 col0" >739</td>
#             </tr>
#             <tr>
#                         <th id="T_24c3206e_9e81_11ea_a667_e442a6e5747clevel0_row8" class="row_heading level0 row8" >Andhra Pradesh</th>
#                         <td id="T_24c3206e_9e81_11ea_a667_e442a6e5747crow8_col0" class="data row8 col0" >727</td>
#             </tr>
#             <tr>
#                         <th id="T_24c3206e_9e81_11ea_a667_e442a6e5747clevel0_row9" class="row_heading level0 row9" >West Bengal</th>
#                         <td id="T_24c3206e_9e81_11ea_a667_e442a6e5747crow9_col0" class="data row9 col0" >391</td>
#             </tr>
#             <tr>
#                         <th id="T_24c3206e_9e81_11ea_a667_e442a6e5747clevel0_row10" class="row_heading level0 row10" >Jammu and Kashmir</th>
#                         <td id="T_24c3206e_9e81_11ea_a667_e442a6e5747crow10_col0" class="data row10 col0" >330</td>
#             </tr>
#             <tr>
#                         <th id="T_24c3206e_9e81_11ea_a667_e442a6e5747clevel0_row11" class="row_heading level0 row11" >Karnataka</th>
#                         <td id="T_24c3206e_9e81_11ea_a667_e442a6e5747crow11_col0" class="data row11 col0" >283</td>
#             </tr>
#             <tr>
#                         <th id="T_24c3206e_9e81_11ea_a667_e442a6e5747clevel0_row12" class="row_heading

# %% [markdown]
# # COVID-19 Cases By State Chart in India

# %%
#to arrange use object oriented mathub

df.iplot(kind='scatter',x='Name of State / UT' ,y='Total Cases')
# Out:
# <div>
#
#
#             <div id="15430ab9-8eda-4345-9b00-4f80dc56a436" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("15430ab9-8eda-4345-9b00-4f80dc56a436")) {
#                     Plotly.newPlot(
#                         '15430ab9-8eda-4345-9b00-4f80dc56a436',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Total Cases", "text": "", "type": "scatter", "x": ["Andhra Pradesh", "Chhattisgarh", "Delhi", "Gujarat", "Haryana", "Himachal Pradesh", "Karnataka", "Kerala", "Madhya Pradesh", "Maharashtra", "Odisha", "Puducherry", "Punjab", "Rajasthan", "Tamil Nadu", "Telengana", "Chandigarh", "Jammu and Kashmir", "Ladakh", "Uttar Pradesh", "Uttarakhand", "West Bengal", "Bihar", "Mizoram", "Goa", "Manipur", "Arunchal Pradesh", "Assam", "Tripura ", "Jharkhand", "Meghalaya"], "y": [895, 36, 2377, 2624, 286, 40, 445, 447, 1699, 6430, 90, 7, 277, 1964, 1683, 960, 27, 427, 18, 1511, 47, 514, 153, 1, 7, 2, 1, 36, 2, 53, 12]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {" ...

# %%
df.iplot(kind='scatter',x='Name of State / UT' ,y='Death'
         ,mode='markers+lines',title='My Graph',xTitle='Name of State / UT',yTitle='Death',colors='red',size=20)
px.scatter(df,x='Name of State / UT',y='Cured')
# Out:
# <div>
#
#
#             <div id="d1805d7f-5836-4431-83f2-79f3fd419820" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("d1805d7f-5836-4431-83f2-79f3fd419820")) {
#                     Plotly.newPlot(
#                         'd1805d7f-5836-4431-83f2-79f3fd419820',
#                         [{"line": {"color": "rgba(219, 64, 82, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "marker": {"size": 20, "symbol": "circle"}, "mode": "markers+lines", "name": "Death", "text": "", "type": "scatter", "x": ["Andhra Pradesh", "Chhattisgarh", "Delhi", "Gujarat", "Haryana", "Himachal Pradesh", "Karnataka", "Kerala", "Madhya Pradesh", "Maharashtra", "Odisha", "Puducherry", "Punjab", "Rajasthan", "Tamil Nadu", "Telengana", "Chandigarh", "Jammu and Kashmir", "Ladakh", "Uttar Pradesh", "Uttarakhand", "West Bengal", "Bihar", "Mizoram", "Goa", "Manipur", "Arunchal Pradesh", "Assam", "Tripura ", "Jharkhand", "Meghalaya"], "y": [27, 0, 50, 112, 3, 1, 17, 3, 83, 283, 1, 0, 16, 27, 20, 24, 0, 5, 0, 24, 0, 20, 2, 0, 0, 0, 0, 1, 5, 3, 1]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {" ...
# <div>
#
#
#             <div id="a74a97d4-22c3-4248-84af-b3e3ed496945" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a74a97d4-22c3-4248-84af-b3e3ed496945")) {
#                     Plotly.newPlot(
#                         'a74a97d4-22c3-4248-84af-b3e3ed496945',
#                         [{"hovertemplate": "Name of State / UT=%{x}<br>Cured=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "", "showlegend": false, "type": "scatter", "x": ["Andhra Pradesh", "Chhattisgarh", "Delhi", "Gujarat", "Haryana", "Himachal Pradesh", "Karnataka", "Kerala", "Madhya Pradesh", "Maharashtra", "Odisha", "Puducherry", "Punjab", "Rajasthan", "Tamil Nadu", "Telengana", "Chandigarh", "Jammu and Kashmir", "Ladakh", "Uttar Pradesh", "Uttarakhand", "West Bengal", "Bihar", "Mizoram", "Goa", "Manipur", "Arunchal Pradesh", "Assam", "Tripura ", "Jharkhand", "Meghalaya"], "xaxis": "x", "y": [141, 28, 808, 258, 156, 18, 145, 324, 203, 840, 33, 3, 65, 230, 752, 197, 14, 92, 14, 206, 24, 103, 46, 0, 7, 2, 1, 19, 1, 8, 0], "yaxis": "y"}],
#                         {"legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpola ...

# %%
import plotly.graph_objects as go
labels = ['Andhra Pradesh','Chhattisgarh','Delhi','Gujarat','Haryana','Himachal Pradesh','Karnataka','Kerala',
'Madhya Pradesh','Maharashtra','Odisha','Puducherry','Punjab','Rajasthan','Tamil Nadu','Telengana','Chandigarh',
'Jammu and Kashmir','Ladakh','Uttar Pradesh','Uttarakhand','West Bengal','Bihar','Mizoram','Goa','Manipur','Arunchal Pradesh',
'Assam','Tripura', 'Jharkhand','Meghalaya']
values = [27,0,50,112,3,1,17,3,83,283,1,0,16,27,20,24,0,5,0,24,0,20,2,0,0,0,0,1,5,3]

fig = go.Figure(data=[go.Pie(labels=labels, values=values)])
fig.show()
# Out:
# <div>
#
#
#             <div id="099f2985-ec6e-445a-8707-7f01d5cb40d7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("099f2985-ec6e-445a-8707-7f01d5cb40d7")) {
#                     Plotly.newPlot(
#                         '099f2985-ec6e-445a-8707-7f01d5cb40d7',
#                         [{"labels": ["Andhra Pradesh", "Chhattisgarh", "Delhi", "Gujarat", "Haryana", "Himachal Pradesh", "Karnataka", "Kerala", "Madhya Pradesh", "Maharashtra", "Odisha", "Puducherry", "Punjab", "Rajasthan", "Tamil Nadu", "Telengana", "Chandigarh", "Jammu and Kashmir", "Ladakh", "Uttar Pradesh", "Uttarakhand", "West Bengal", "Bihar", "Mizoram", "Goa", "Manipur", "Arunchal Pradesh", "Assam", "Tripura", "Jharkhand", "Meghalaya"], "type": "pie", "values": [27, 0, 50, 112, 3, 1, 17, 3, 83, 283, 1, 0, 16, 27, 20, 24, 0, 5, 0, 24, 0, 20, 2, 0, 0, 0, 0, 1, 5, 3]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...

# %%
# displaying the total stats

display(HTML("<div style = 'background-color: #504e4e; padding: 30px '>" +
             "<span style='color: #fff; font-size:30px; font-weight:bold;font-family:roboto'> Confirmed: "  + str(confirmed_total) +"</span>" +
             "<span style='color: red; font-size:30px;margin-left:20px;font-weight:bold;font-family:roboto'> Deaths: " + str(deaths_total) + "</span>"+
             "<span style='color: lightgreen; font-size:30px; margin-left:20px;font-weight:bold;font-family:roboto'> Recovered: " + str(recovered_total) + "</span>"+
             "</div>")
       )
# Out:
# <div style = 'background-color: #504e4e; padding: 30px '><span style='color: #fff; font-size:30px; font-weight:bold;font-family:roboto'> Confirmed: 5428605</span><span style='color: red; font-size:30px;margin-left:20px;font-weight:bold;font-family:roboto'> Deaths: 345375</span><span style='color: lightgreen; font-size:30px; margin-left:20px;font-weight:bold;font-family:roboto'> Recovered: 2180016</span></div>

# %% [raw]
# # COVID-19 Confirmed/Death/Recovered cases by countries
#
# ## Enter number of countries you want the data for

# %%
# sorting the values by confirmed descednding order
# country_df.sort_values('confirmed', ascending= False).head(10).style.background_gradient(cmap='copper')
fig = go.FigureWidget( layout=go.Layout() )
def highlight_col(x):
    r = 'background-color: red'
    y = 'background-color: purple'
    g = 'background-color: grey'
    df1 = pd.DataFrame('', index=x.index, columns=x.columns)
    df1.iloc[:, 4] = y
    df1.iloc[:, 5] = r
    df1.iloc[:, 6] = g
    
    return df1

def show_latest_cases(n):
    n = int(n)
    return country_df.sort_values('confirmed', ascending= False).head(n).style.apply(highlight_col, axis=None)

interact(show_latest_cases, n='10')

ipywLayout = widgets.Layout(border='solid 2px green')
ipywLayout.display='none' # uncomment this, run cell again - then the graph/figure disappears
widgets.VBox([fig], layout=ipywLayout)
# Out:
# interactive(children=(Text(value='10', description='n'), Output()), _dom_classes=('widget-interact',))
# VBox(children=(FigureWidget({
#     'data': [], 'layout': {'template': '...'}
# }),), layout=Layout(border='solid …

# %%
sorted_country_df = country_df.sort_values('confirmed', ascending= False)

# %% [markdown]
# # Slide to check for the worst hit countries

# %%
# # plotting the 20 worst hit countries

def bubble_chart(n):
    fig = px.scatter(sorted_country_df.head(n), x="country", y="confirmed", size="confirmed", color="country",
               hover_name="country", size_max=60)
    fig.update_layout(
    title=str(n) +" Worst hit countries",
    xaxis_title="Countries",
    yaxis_title="Confirmed Cases",
    width = 700
    )
    fig.show();

interact(bubble_chart, n=10)

ipywLayout = widgets.Layout(border='solid 2px green')
ipywLayout.display='none'
widgets.VBox([fig], layout=ipywLayout)
# Out:
# interactive(children=(IntSlider(value=10, description='n', max=30, min=-10), Output()), _dom_classes=('widget-…
# VBox(children=(FigureWidget({
#     'data': [], 'layout': {'template': '...'}
# }),), layout=Layout(border='solid …

# %%
def plot_cases_of_a_country(country):
    labels = ['confirmed', 'deaths']
    colors = ['blue', 'red']
    mode_size = [6, 8]
    line_size = [4, 5]
    
    df_list = [confirmed_df, death_df]
    
    fig = go.Figure();
    
    for i, df in enumerate(df_list):
        if country == 'World' or country == 'world':
            x_data = np.array(list(df.iloc[:, 20:].columns))
            y_data = np.sum(np.asarray(df.iloc[:,4:]),axis = 0)
            
        else:    
            x_data = np.array(list(df.iloc[:, 20:].columns))
            y_data = np.sum(np.asarray(df[df['country'] == country].iloc[:,20:]),axis = 0)
            
        fig.add_trace(go.Scatter(x=x_data, y=y_data, mode='lines+markers',
        name=labels[i],
        line=dict(color=colors[i], width=line_size[i]),
        connectgaps=True,
        text = "Total " + str(labels[i]) +": "+ str(y_data[-1])
        ));
        
    
    fig.update_layout(
        title="COVID 19 cases of " + country,
        xaxis_title='Date',
        yaxis_title='No. of Confirmed Cases',
        margin=dict(l=20, r=20, t=40, b=20),
        paper_bgcolor="lightgrey",
        width = 800,
        
    );
    
    fig.update_yaxes(type="linear")
    fig.show();

# %% [markdown]
# # Check the details of your country or the World
#
# * Enter the name of your country(in capitalized format(e.g. Italy)) and world for total cases

# %%
interact(plot_cases_of_a_country, country='World')

ipywLayout = widgets.Layout(border='solid 2px green')
ipywLayout.display='none' # uncomment this, run cell again - then the graph/figure disappears
widgets.VBox([fig], layout=ipywLayout)
# Out:
# interactive(children=(Text(value='World', description='country'), Output()), _dom_classes=('widget-interact',)…
# VBox(children=(FigureWidget({
#     'data': [], 'layout': {'template': '...'}
# }),), layout=Layout(border='solid …

# %% [markdown]
# # 10 worst hit countries - Confirmed cases

# %%
px.bar(
    sorted_country_df.head(10),
    x = "country",
    y = "confirmed",
    title= "Top 10 worst affected countries", # the axis names
    color_discrete_sequence=["pink"], 
    height=500,
    width=800
)
# Out:
# <div>
#
#
#             <div id="a0b21bcb-f003-4fa0-a678-e9bd0e78e33e" class="plotly-graph-div" style="height:500px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a0b21bcb-f003-4fa0-a678-e9bd0e78e33e")) {
#                     Plotly.newPlot(
#                         'a0b21bcb-f003-4fa0-a678-e9bd0e78e33e',
#                         [{"alignmentgroup": "True", "hovertemplate": "country=%{x}<br>confirmed=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "pink"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["US", "Brazil", "Russia", "United Kingdom", "Spain", "Italy", "France", "Germany", "Turkey", "India"], "xaxis": "x", "y": [1643499.0, 363211.0, 353427.0, 260916.0, 235772.0, 229858.0, 182709.0, 180338.0, 156827.0, 139911.0], "yaxis": "y"}],
#                         {"barmode": "relative", "height": 500, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "ty ...

# %% [markdown]
# # 10 worst hit countries - Death cases

# %%
px.bar(
    sorted_country_df.head(10),
    x = "country",
    y = "deaths",
    title= "Top 10 worst affected countries", # the axis names
    color_discrete_sequence=["pink"], 
    height=500,
    width=800
)
# Out:
# <div>
#
#
#             <div id="b4db2671-7702-49f3-90f3-f4f25c34821e" class="plotly-graph-div" style="height:500px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b4db2671-7702-49f3-90f3-f4f25c34821e")) {
#                     Plotly.newPlot(
#                         'b4db2671-7702-49f3-90f3-f4f25c34821e',
#                         [{"alignmentgroup": "True", "hovertemplate": "country=%{x}<br>deaths=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "pink"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["US", "Brazil", "Russia", "United Kingdom", "Spain", "Italy", "France", "Germany", "Turkey", "India"], "xaxis": "x", "y": [97722.0, 22666.0, 3633.0, 36875.0, 28752.0, 32785.0, 28370.0, 8287.0, 4340.0, 4039.0], "yaxis": "y"}],
#                         {"barmode": "relative", "height": 500, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "ty ...

# %% [markdown]
# # Worst hit countries - Recovering cases

# %%
px.bar(
    sorted_country_df.head(10),
    x = "country",
    y = "recovered",
    title= "Top 10 worst affected countries", # the axis names
    color_discrete_sequence=["pink"], 
    height=500,
    width=800
)
# Out:
# <div>
#
#
#             <div id="818a1a42-ea22-4adb-9c88-a99ef6f976f6" class="plotly-graph-div" style="height:500px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("818a1a42-ea22-4adb-9c88-a99ef6f976f6")) {
#                     Plotly.newPlot(
#                         '818a1a42-ea22-4adb-9c88-a99ef6f976f6',
#                         [{"alignmentgroup": "True", "hovertemplate": "country=%{x}<br>recovered=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "pink"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["US", "Brazil", "Russia", "United Kingdom", "Spain", "Italy", "France", "Germany", "Turkey", "India"], "xaxis": "x", "y": [366736.0, 149911.0, 118798.0, 1151.0, 150376.0, 140479.0, 64735.0, 160903.0, 118694.0, 57976.0], "yaxis": "y"}],
#                         {"barmode": "relative", "height": 500, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "ty ...

# %% [markdown]
# # Global spread of COVID-19

# %%
world_map = folium.Map(location=[11,0], tiles="cartodbdark_matter", zoom_start=2, max_zoom = 6, min_zoom = 2)


for i in range(0,len(confirmed_df)):
    folium.Circle(
        location=[confirmed_df.iloc[i]['lat'], confirmed_df.iloc[i]['long']],
        fill=True,
        radius=(int((np.log(confirmed_df.iloc[i,-1]+1.00001)))+0.2)*50000,
        color='red',
        fill_color='indigo',
        tooltip = "<div style='margin: -20px; background-color: black; color: white;padding-left:10px;padding-top:10px;padding-right:10px;padding-bottom:10px;font-family:roboto'>"+
                    "<h4 style='text-align:center;font-weight: bold;font-family:roboto'>"+confirmed_df.iloc[i]['country'] + "</h4>"
                    "<hr style='margin:10px;color: white;font-family:roboto'>"+
                    "<ul style='color: white;;list-style-type:circle;align-item:left;padding-left:20px;padding-right:20px;font-family:roboto'>"+
                        "<li>Confirmed: "+str(confirmed_df.iloc[i,-1])+"</li>"+
                        "<li>Deaths:   "+str(death_df.iloc[i,-1])+"</li>"+
                        "<li>Death Rate: "+ str(np.round(death_df.iloc[i,-1]/(confirmed_df.iloc[i,-1]+1.00001)*100,2))+ "</li>"+
                    "</ul></div>",
        ).add_to(world_map)

world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_latlong=pd.merge(sorted_country_df,confirmed_df,on=['country'])

# %%
#confirmed_df.head(5)

# %%
fig=px.density_mapbox(df_latlong,lat="lat_x",lon="long_",hover_name="country",hover_data=["confirmed","deaths","recovered"],animation_frame='last_update',color_continuous_scale="Portland",radius=7,zoom=0,height=700)
fig.update_layout(title='Worldwide Corona Virus Cases')
fig.update_layout(mapbox_style="carto-darkmatter",mapbox_center_lon=0)
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
# Out:
# <div>
#
#
#             <div id="76b55645-42fd-4e4e-b799-08dc3d3fce0f" class="plotly-graph-div" style="height:700px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("76b55645-42fd-4e4e-b799-08dc3d3fce0f")) {
#                     Plotly.newPlot(
#                         '76b55645-42fd-4e4e-b799-08dc3d3fce0f',
#                         [{"coloraxis": "coloraxis", "customdata": [[1643499.0, 97722.0, 366736.0], [363211.0, 22666.0, 149911.0], [353427.0, 3633.0, 118798.0], [260916.0, 36875.0, 1151.0], [260916.0, 36875.0, 1151.0], [260916.0, 36875.0, 1151.0], [260916.0, 36875.0, 1151.0], [260916.0, 36875.0, 1151.0], [260916.0, 36875.0, 1151.0], [260916.0, 36875.0, 1151.0], [260916.0, 36875.0, 1151.0], [260916.0, 36875.0, 1151.0], [260916.0, 36875.0, 1151.0], [260916.0, 36875.0, 1151.0], [235772.0, 28752.0, 150376.0], [229858.0, 32785.0, 140479.0], [182709.0, 28370.0, 64735.0], [182709.0, 28370.0, 64735.0], [182709.0, 28370.0, 64735.0], [182709.0, 28370.0, 64735.0], [182709.0, 28370.0, 64735.0], [182709.0, 28370.0, 64735.0], [182709.0, 28370.0, 64735.0], [182709.0, 28370.0, 64735.0], [182709.0, 28370.0, 64735.0], [182709.0, 28370.0, 64735.0], [182709.0, 28370.0, 64735.0], [180338.0, 8287.0, 160903.0], [156827.0, 4340.0, 118694.0], [139911.0, 4039.0, 57976.0], [137724.0, 7451.0, 107713.0], [119959.0, 3456.0, 49795.0], [86106.0, 6534.0, 43998.0], [86106.0, 6534.0, 43998.0], [86106.0, 6534.0, 43998.0], [86106.0, 6534.0, 43998.0], [86106.0, 6534.0, 43998.0], [86106.0, 6534.0, 43998.0], [86106.0, 6534.0, 43998.0], [86106.0, 6534.0, 43998.0], [86106.0, 6534.0, 43998.0], [86106.0, 6534.0, 43998.0], [86106.0, 6534.0, 43998.0], [86106.0, 6534.0, 43998.0], [86106.0, 6534.0, 43998.0], [86106.0, 6534.0, 43998.0], [84095.0, 4638.0, 79347.0], [84095.0, 4638.0, 79347.0], [84095.0, 4638.0, 79347.0], [84095.0, 4638.0, 79347.0], [84095.0, 4638.0, 79347.0], [84095.0, 4638.0, 79347.0], [84095.0, 4638.0, 79347.0], [84095.0, 4638.0, 79347.0], [84095.0, 4638.0, 79347.0], [84095.0, 4638.0, 79347.0], [84095.0, 4638.0, 79347.0], [84095.0, 4638.0, 79347.0], [84095.0, 4638.0, 79347.0], [84095.0, 4638.0, 79347.0], [84095.0, 4638.0, 79347.0], [84095.0, 4638.0, 79347.0], [84095.0, 4638.0, 79347.0], [84095.0, 4638.0, 79347.0], [84095.0, 4638.0, 79347.0], [84095.0, 4638.0, 79347.0], [84095.0, 4638.0, 79347.0], [84095.0, 4638.0, 79347.0], [84095.0, 4638.0, 79347.0], [84095.0, 4638.0, 79347.0], [84095.0, 4638.0, 79347.0], [84095.0, 4638.0, 79347.0], [84095.0, 4638.0, 79347.0], [84095.0, 4638.0, 79347.0], [84095.0, 4638.0, 79347.0], [84095.0, 4638.0, 79347.0], [84095.0, 4638.0, 79347.0], [84095.0, 4638.0, 79347.0], [84095.0, 4638.0, 79347.0], [72560.0, 390.0, 43520.0], [69102.0, 718.0, 28148.0], [68620.0, 7394.0, 46979.0], [57342.0, 9312.0, 15297.0], [56349.0, 1167.0, 17482.0], [45437.0, 5841.0, 174.0], [45437.0, 5841.0, 174.0], [45437.0, 5841.0, 174.0], [45437.0, 5841.0, 174.0], [45437.0, 5841.0, 174.0], [43714.0, 23.0, 9170.0], [36756.0, 3108.0, 3560.0], [36198.0, 199.0, 14155.0], [35585.0, 501.0, 7334.0], [33459.0, 3998.0, 4971.0], [31960.0, 23.0, 14876.0], [30746.0, 1907.0, 28100.0], [30623.0, 1316.0, 17549.0], [29485.0, 245.0, 15056.0], [24639.0, 1608.0, 21060.0], [22750.0, 1391.0, 5642.0], [22583.0, 429.0, 11100.0], [21967.0, 165.0, 6621.0], [21440.0, 996.0, 9276.0], [21245.0, 623.0, 7234.0], [21175.0, 727.0, 5016.0], [18283.0, 1197.0, 11630.0], [17265.0, 764.0, 4807.0], [16720.0, 280.0, 14203.0], [16550.0, 820.0, 13413.0], [16539.0, 641.0, 15138.0], [14801.0, 458.0, 8133.0], [14319.0, 873.0, 3323.0], [12076.0, 452.0, 3732.0], [11559.0, 562.0, 10098.0], [11559.0, 562.0, 10098.0], [11559.0, 562.0, 10098.0], [11206.0, 267.0, 10226.0], [11173.0, 219.0, 1097.0], [11159.0, 238.0, 5857.0], [10926.0, 306.0, 6279.0], [9138.0, 14.0, 4587.0], [8957.0, 315.0, 6083.0], [8531.0, 35.0, 4400.0], [8352.0, 235.0, 7727.0], [8306.0, 600.0, 4784.0], [7839.0, 226.0, 2263.0], [7770.0, 37.0, 1933.0], [7495.0, 200.0, 4737.0], [7417.0, 115.0, 5979.0], [7118.0, 102.0, 6532.0], [7118.0, 102.0, 6532.0], [7118.0, 102.0, 6532.0], [7118.0, 102.0, 6532.0], [7118.0, 102.0, 6532.0], [7118.0, 102.0, 6532.0], [7118.0, 102.0, 6532.0], [7118.0, 102.0, 6532.0], [7113.0, 87.0, 3145.0], [7093.0, 256.0, 3802.0], [6808.0, 32.0, 2070.0], [6599.0, 308.0, 5100.0], [6263.0, 250.0, 629.0], [4890.0, 165.0, 1865.0], [4 ...

# %% [markdown]
# # Timeseries Forecasting of COVID-19

# %%
# importing necessary modules

from statsmodels.tsa.seasonal import seasonal_decompose 
from pandas import read_csv
from matplotlib import pyplot
# load dataset
series = read_csv('https://raw.githubusercontent.com/rahulagarwal01/Covid_19_Datasets/master/dataset2.csv')
# display first few rows
#print(series.head(20))

# %%
series['date'] = pd.DatetimeIndex(series['date'])
#series.dtypes

# %%
series = series[series.new_cases != 0]
series.head()
# Out:
#          date  TotalCase  new_cases  total_deaths  new_deaths  \
# 30 2020-01-30          1          1             0           0
# 33 2020-02-02          2          1             0           0
# 35 2020-04-02          3          1             0           0
# 63 2020-03-03          5          2             0           0
# 64 2020-04-03          6          1             0           0
#
#     total_cases_per_million  new_cases_per_million  total_deaths_per_million  \
# 30                    0.001                  0.001                       0.0
# 33                    0.001                  0.001                       0.0
# 35                    0.002                  0.001                       0.0
# 63                    0.004                  0.001                       0.0
# 64                    0.004                  0.001                       0.0
#
#     new_deaths_per_million  total_tests  ...  aged_65_older  aged_70_older  \
# 30                     0.0          NaN  ...          5.989          3.414
# 33                     0.0          NaN  ...          5.989          3.414
# 35                     0.0          NaN  ...          5.989          3.414
# 63                     0.0          NaN  ...          5.989          3.414
# 64                     0.0          NaN  ...          5.989          3.414
#
#     gdp_per_capita  extreme_poverty  cvd_death_rate diabetes_prevalence  \
# 30        6426.674             21.2          282.28               10.39
# 33        6426.674             21.2          282.28               10.39
# 35        6426.674             21.2          282.28               10.39
# 63        6426.674             21.2          282.28               10.39
# 64        6426.674             21.2          282.28               10.39
#
#     Unnamed: 26  Unnamed: 27  Unnamed: 28  Unnamed: 29
# 30          1.9         20.6        59.55         0.53
# 33          1.9         20.6        59.55         0.53
# 35          1.9         20.6        59.55         0.53
# 63          1.9         20.6        59.55         0.53
# 64          1.9         20.6        59.55         0.53
#
# [5 rows x 30 columns]

# %%
result = seasonal_decompose(series['new_cases'],  
                            model ='additive',period=5) 
  
# ETS plot  
result.plot()

# %%
from pmdarima import auto_arima 
  
# Ignore harmless warnings 
import warnings 
warnings.filterwarnings("ignore") 
  
# Fit auto_arima function to AirPassengers dataset 
stepwise_fit = auto_arima(series['new_cases'], start_p = 1, start_q = 1, 
                          max_p = 3, max_q = 3, m = 12, 
                          start_P = 0, seasonal = True, 
                          d = None, D = 1, trace = True, 
                          error_action ='ignore',   # we don't want to know if an order does not work 
                          suppress_warnings = True,  # we don't want convergence warnings 
                          stepwise = True)           # set to stepwise 
  
# To print the summary 
stepwise_fit.summary()
# Out:
# Performing stepwise search to minimize aic
# Fit ARIMA(1,1,1)x(0,1,1,12) [intercept=True]; AIC=994.198, BIC=1005.441, Time=0.392 seconds
# Fit ARIMA(0,1,0)x(0,1,0,12) [intercept=True]; AIC=1043.128, BIC=1047.625, Time=0.013 seconds
# Fit ARIMA(1,1,0)x(1,1,0,12) [intercept=True]; AIC=994.243, BIC=1003.237, Time=0.420 seconds
# Fit ARIMA(0,1,1)x(0,1,1,12) [intercept=True]; AIC=1000.126, BIC=1009.120, Time=0.419 seconds
# Fit ARIMA(0,1,0)x(0,1,0,12) [intercept=False]; AIC=1041.814, BIC=1044.062, Time=0.013 seconds
# Fit ARIMA(1,1,1)x(0,1,0,12) [intercept=True]; AIC=1002.308, BIC=1011.302, Time=0.099 seconds
# Fit ARIMA(1,1,1)x(1,1,1,12) [intercept=True]; AIC=996.184, BIC=1009.675, Time=0.592 seconds
# Fit ARIMA(1,1,1)x(0,1,2,12) [intercept=True]; AIC=996.184, BIC=1009.675, Time=0.745 seconds
# Fit ARIMA(1,1,1)x(1,1,0,12) [intercept=True]; AIC=994.877, BIC=1006.120, Time=0.550 seconds
# Fit ARIMA(1,1,1)x(1,1,2,12) [intercept=True]; AIC=998.187, BIC=1013.926, Time=1.201 seconds
# Fit ARIMA(1,1,0)x(0,1,1,12) [intercept=True]; AIC=992.661, BIC=1001.655, Time=0.310 seconds
# Fit ARIMA(1,1,0)x(0,1,0,12) [intercept=True]; AIC=1001.111, BIC=1007.857, Time=0.027 seconds
# Fit ARIMA(1,1,0)x(1,1,1,12) [intercept=True]; AIC=994.661, BIC=1005.903, Time=0.429 seconds
# Fit ARIMA(1,1,0)x(0,1,2,12) [intercept=True]; AIC=994.633, BIC=1005.876, Time=1.057 seconds
# Fit ARIMA(1,1,0)x(1,1,2,12) [intercept=True]; AIC=996.643, BIC=1010.134, Time=1.000 seconds
# Fit ARIMA(0,1,0)x(0,1,1,12) [intercept=True]; AIC=1022.342, BIC=1029.087, Time=0.296 seconds
# Fit ARIMA(2,1,0)x(0,1,1,12) [intercept=True]; AIC=994.401, BIC=1005.644, Time=0.346 seconds
# Fit ARIMA(2,1,1)x(0,1,1,12) [intercept=True]; AIC=995.680, BIC=1009.171, Time=0.769 seconds
# Total fit time: 8.697 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                    y   No. Observations:                   83
# Model:             SARIMAX(1, 1, 0)x(0, 1, [1], 12)   Log Likelihood                -492.331
# Date:                              Mon, 25 May 2020   AIC                            992.661
# Time:                                      17:44:41   BIC                           1001.655
# Sample:                                           0   HQIC                           996.234
#                                                - 83
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     58.1968     19.795      2.940      0.003      19.399      96.994
# ar.L1         -0.6145      0.087     -7.055      0.000      -0.785      -0.444
# ma.S.L12      -0.5150      0.163     -3.152      0.002      -0.835      -0.195
# sigma2      7.156e+04   9406.530      7.607      0.000    5.31e+04       9e+04
# ===================================================================================
# Ljung-Box (Q):                       34.74   Jarque-Bera (JB):                43.85
# Prob(Q):                              0.71   Prob(JB):                         0.00
# Heteroskedasticity (H):              20.97   Skew:                             1.13
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.14
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
train = series.iloc[:len(series)-43] 
test = series.iloc[len(series)-40:] # set one year(12 months) for testing 
  
# Fit a SARIMAX(0, 1, 1)x(2, 1, 1, 12) on the training set 
from statsmodels.tsa.statespace.sarimax import SARIMAX 
  
model = SARIMAX(train['new_cases'],  
                order = (1, 1, 0),  
                seasonal_order =(0, 1, [1], 12)) 
  
result = model.fit() 
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                            new_cases   No. Observations:                   40
# Model:             SARIMAX(1, 1, 0)x(0, 1, [1], 12)   Log Likelihood                -163.390
# Date:                              Mon, 25 May 2020   AIC                            332.780
# Time:                                      17:44:41   BIC                            336.667
# Sample:                                           0   HQIC                           333.936
#                                                - 40
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.8275      0.136     -6.076      0.000      -1.094      -0.561
# ma.S.L12      -0.0714      0.808     -0.088      0.930      -1.654       1.512
# sigma2      1.016e+04   1509.147      6.731      0.000    7199.443    1.31e+04
# ===================================================================================
# Ljung-Box (Q):                        8.06   Jarque-Bera (JB):                39.45
# Prob(Q):                              1.00   Prob(JB):                         0.00
# Heteroskedasticity (H):              52.83   Skew:                             1.42
# Prob(H) (two-sided):                  0.00   Kurtosis:                         8.19
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
start = len(train) 
end = len(train) + len(test) - 1
  
# Predictions for one-year against the test set 
predictions = result.predict(start, end, 
                             typ = 'levels').rename("Predictions") 
  
# plot predictions and actual values 
predictions.plot(legend = True) 
test['new_cases'].plot(legend = True)

# %%
# Load specific evaluation tools 
from sklearn.metrics import mean_squared_error 
from statsmodels.tools.eval_measures import rmse 
  
# Calculate root mean squared error 
rmse(test["new_cases"], predictions)
# Out:
# 1656.7143079062396

# %%
# Calculate mean squared error 
mean_squared_error(test["new_cases"], predictions)
# Out:
# 2744702.2980212504

# %%
# Train the model on the full dataset 
model = model = SARIMAX(series['new_cases'],  
                        order = (1, 1, 0),  
                        seasonal_order =(0, 1, 1, 12)) 
result = model.fit() 
  
# Forecast for the next 3 years 
forecast = result.predict(start = len(series),  
                          end = (len(series)-1) + 3 * 12,  
                          typ = 'levels').rename('Forecast') 
  
# Plot the forecast values 
series['new_cases'].plot(figsize = (12, 5), legend = True) 
forecast.plot(legend = True)
